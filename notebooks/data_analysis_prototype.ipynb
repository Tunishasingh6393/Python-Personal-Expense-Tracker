# %% [markdown]
# # 📊 Expense Data Exploration
# This notebook contains the initial prototype for the categorization engine and spending trend analysis.

# %%
import pandas as pd
df = pd.read_csv('../data/sample_ledger.csv')
print(df.groupby('Account')['Amount'].sum())
